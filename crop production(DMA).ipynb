# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

# %%
crop = pd.read_csv("C:/Users/HP/Documents/Datasets/apy.csv")

# %%
crop
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
crop.isna().count
# Out:
# <bound method DataFrame.count of         State_Name  District_Name  Crop_Year  Season   Crop   Area  Production
# 0            False          False      False   False  False  False       False
# 1            False          False      False   False  False  False       False
# 2            False          False      False   False  False  False       False
# 3            False          False      False   False  False  False       False
# 4            False          False      False   False  False  False       False
# ...            ...            ...        ...     ...    ...    ...         ...
# 246086       False          False      False   False  False  False       False
# 246087       False          False      False   False  False  False       False
# 246088       False          False      False   False  False  False       False
# 246089       False          False      False   False  False  False       False
# ...

# %%
crop.Season.unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
(ggplot(crop)         # defining what data to use
 + aes(x='Season')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)
# Out:
# <ggplot: (-9223371890333357070)>

# %%
(ggplot(crop)
 + aes(x='Crop_Year', y='Production', color='Production')
 + geom_point()
 + labs(title='crop production every year', x='Crop_Year', y='Production')
)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\mizani\bounds.py:352: RuntimeWarning: invalid value encountered in less
#   outside = (x < range[0]) | (x > range[1])
# C:\Users\HP\Anaconda3\lib\site-packages\mizani\bounds.py:352: RuntimeWarning: invalid value encountered in greater
#   outside = (x < range[0]) | (x > range[1])
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\HP\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_point : Removed 3730 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (146521437988)>

# %%
(ggplot(crop)
 + aes(x='Area', y='State_Name', color='State_Name')
 + geom_point()
 + labs(title='State wise crop production', x='Area', y='State_Name')
)
# Out:
# <ggplot: (-9223371935778370076)>

# %%
(ggplot(crop)
 + aes(x='Production', y='State_Name', color='State_Name')
 + geom_point()
 + labs(title='state wise production', x='Production', y='State_Name')
)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_point : Removed 3730 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223371935774414655)>

# %%
crop.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Rapeseed &Mustard', 'Mesta',
#        'Cowpea(Lobia)', 'Lemon', 'Pome Granet', 'Sapota', 'Cabbage',
# ...

# %%
crop.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
crop.groupby('Crop').count()

# %%
df=crop.groupby('State_Name').count()
df
# Out:
#                              District_Name  Crop_Year  Season   Crop   Area  \
# State_Name
# Andaman and Nicobar Islands            203        203     203    203    203
# Andhra Pradesh                        9628       9628    9628   9628   9628
# Arunachal Pradesh                     2546       2546    2546   2546   2546
# Assam                                14628      14628   14628  14628  14628
# Bihar                                18885      18885   18885  18885  18885
# Chandigarh                              90         90      90     90     90
# Chhattisgarh                         10709      10709   10709  10709  10709
# Dadra and Nagar Haveli                 263        263     263    263    263
# Goa                                    208        208     208    208    208
# Gujarat                               8436       8436    8436   8436   8436
# Haryana                               5875       5875    5875   5875   5875
# ...

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(50,50))
x = [1,2,3]
df1.plot(figsize=(13,10))
plt.show()

# %%
crop.State_Name.unique()

# %%
crop.Crop.unique()

# %%
import seaborn as sns

# %%
import matplotlib.style
matplotlib.style.use('ggplot')


fig = plt.subplots(figsize= (10,10),dpi =200)
sns.set(font_scale =1.5)
sns.heatmap(crop.corr(),square=True, cbar=True, annot=True)

# %%
crop.groupby('Crop_Year').count()
# Out:
#            State_Name  District_Name  Season   Crop   Area  Production
# Crop_Year
# 1997             8899           8899    8899   8899   8899        8899
# 1998            11533          11533   11533  11533  11533       11262
# 1999            12515          12515   12515  12515  12515       12441
# 2000            13658          13658   13658  13658  13658       13553
# 2001            13361          13361   13361  13361  13361       13293
# 2002            16671          16671   16671  16671  16671       16536
# 2003            17287          17287   17287  17287  17287       17139
# 2004            14117          14117   14117  14117  14117       13858
# 2005            13799          13799   13799  13799  13799       13519
# 2006            14328          14328   14328  14328  14328       13976
# 2007            14526          14526   14526  14526  14526       14269
# 2008            14550          14550   14550  14550  14550       14230
# ...

# %%
def convert():
    i=1
    for x in crop.Crop.unique():
        crop.Crop.replace(x,i,inplace=True)
        i=i+1
convert()

# %%
def convert():
    i=1
    for x in crop.District_Name.unique():
        crop.District_Name.replace(x,i,inplace=True)
        i=i+1
convert()

# %%
def convert():
    i=1
    for x in crop.State_Name.unique():
        crop.State_Name.replace(x,i,inplace=True)
        i=i+1
convert()

# %%
def convert():
    i=1
    for x in crop.Season.unique():
        crop.Season.replace(x,i,inplace=True)
        i=i+1
convert()

# %%
crop
# Out:
#         State_Name  District_Name  Crop_Year  Season  Crop      Area  \
# 0                1              1       2000       1     1    1254.0
# 1                1              1       2000       1     2       2.0
# 2                1              1       2000       1     3     102.0
# 3                1              1       2000       2     4     176.0
# 4                1              1       2000       2     5     720.0
# ...            ...            ...        ...     ...   ...       ...
# 246086          33            646       2014       5     3     306.0
# 246087          33            646       2014       5    32     627.0
# 246088          33            646       2014       2     8     324.0
# 246089          33            646       2014       6     3  279151.0
# 246090          33            646       2014       6    32     175.0
#
#         Production
# 0           2000.0
# 1              1.0
# 2            321.0
# 3            641.0
# 4            165.0
# ...

# %%
crop.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
crop[crop.Production.isnull()==True]
# Out:
#                          State_Name  District_Name  Crop_Year  Season  Crop  \
# 46      Andaman and Nicobar Islands              1       2005       2     1
# 51      Andaman and Nicobar Islands              1       2005       2    12
# 623                  Andhra Pradesh              4       2007       1    16
# 630                  Andhra Pradesh              4       2007       4    24
# 698                  Andhra Pradesh              4       2009       4    57
# ...                             ...            ...        ...     ...   ...
# 244128                  West Bengal            643       2010       4    74
# 244581                  West Bengal            644       2006       1    16
# 245606                  West Bengal            646       2001       4    57
# 245644                  West Bengal            646       2002       4    57
# 245865                  West Bengal            646       2008       4    79
#
#            Area  Production
# ...

# %%
crop1=crop.groupby('State_Name').mean()

# %%
crop1
# Out:
#                              District_Name    Crop_Year    Season       Crop  \
# State_Name
# Andaman and Nicobar Islands       1.975369  2005.044335  2.275862   7.763547
# Andhra Pradesh                    9.853344  2006.116431  2.290818  23.656211
# Arunachal Pradesh                25.728987  2005.481540  1.857816  26.688924
# Assam                            48.107397  2006.370317  2.579915  28.086205
# Bihar                            80.711835  2005.034101  2.788827  30.153402
# Chandigarh                      100.000000  2002.800000  2.188889  25.800000
# Chhattisgarh                    114.719021  2007.727426  2.170791  30.615183
# Dadra and Nagar Haveli          128.000000  2005.182510  2.783270  25.912548
# Goa                             129.485577  2009.110577  2.052885  16.548077
# Gujarat                         143.302394  2005.159673  2.201991  28.247037
# Haryana                         166.902468  2004.855830  2.103489  30.933617
# ...

# %%
for x in crop1.index:
    crop.loc[(crop.Production.isna()) & (crop.State_Name == x) , 'Production'] = crop1['Production'][x]

# %%
crop['Production'][623]
# Out:
# 1812006.09727016

# %%
X= crop.drop('Season',axis=1)

# %%
X
# Out:
#         State_Name  District_Name  Crop_Year  Crop      Area  Production
# 0                1              1       2000     1    1254.0      2000.0
# 1                1              1       2000     2       2.0         1.0
# 2                1              1       2000     3     102.0       321.0
# 3                1              1       2000     4     176.0       641.0
# 4                1              1       2000     5     720.0       165.0
# ...            ...            ...        ...   ...       ...         ...
# 246086          33            646       2014     3     306.0       801.0
# 246087          33            646       2014    32     627.0       463.0
# 246088          33            646       2014     8     324.0     16250.0
# 246089          33            646       2014     3  279151.0    597899.0
# 246090          33            646       2014    32     175.0        88.0
#
# [246091 rows x 6 columns]

# %%
y=crop['Season']

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         2
# 4         2
#          ..
# 246086    5
# 246087    5
# 246088    2
# 246089    6
# 246090    6
# Name: Season, Length: 246091, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_test
# Out:
# 222211    1
# 148500    6
# 40239     1
# 117       4
# 64394     1
#          ..
# 61852     1
# 86721     2
# 232152    2
# 35199     1
# 205114    1
# Name: Season, Length: 81211, dtype: int64

# %%
y_pred = lm.predict(X_test)
y_pred
# Out:
# array([2.47606664, 2.32162366, 2.76560174, ..., 2.4843139 , 2.30228991,
#        2.36526918])

# %%
X_train.shape
# Out:
# (164880, 6)

# %%
y_train.shape
# Out:
# (164880,)

# %%
from sklearn.svm import SVC
model = SVC(random_state = 1)

# %%
model.fit(X_train,y_train)
model.score(X_test,y_test)*100
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
model.score(X_test,y_test)*100
# Out:
# 6.453559246900051

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 9)

# %%
model.fit(X_train,y_train)
predict = model.predict(X_test)
predict
# Out:
# array([4, 2, 1, ..., 1, 4, 1], dtype=int64)

# %%
model.score(X_test,y_test)*100
# Out:
# 58.17684796394577

# %%
from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier(max_depth=10, random_state=101, max_features=None, min_samples_leaf= 15)

# %%
dtree.fit(X_train,y_train)
y_pred=dtree.predict(X_test)
